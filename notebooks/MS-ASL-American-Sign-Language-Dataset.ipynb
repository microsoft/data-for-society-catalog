# %%
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ## Pre-requisites
#  In order to access the datasets you must create an account, then the download options will appear on the site.
#
# We use the azcopy command here, be sure you have it installed on your environment. You can get it from [here](https://docs.microsoft.com/en-us/azure/storage/common/storage-use-azcopy-v10)

# %% [markdown]
# ### Install dependencies

# %%
pip install pandas==1.4.2

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %% [markdown]
# ### Replace the copied_url variable with the url you got from MSR site:

# %%
# %%sh
# copied_url="https://msropendataset01.blob.core.windows.net/msaslamericansignlanguagedataset?sv=2019-02-02&sr=c&sig=8eA%2F2EfBWmOzXFYo0NiTtH9X5yiodi%2Ft3VU5IIXeJwI%3D&st=2022-05-11T18%3A36%3A58Z&se=2022-06-10T18%3A41%3A58Z&sp=rl"
# dataset_download_path="./asl_dataset"
# azcopy copy $copied_url $dataset_dowload_path  --recursive

# %% [markdown]
# ### Explore the datasets

# %%
# You need to set this variable to the same place where you downloaded the dataset
dataset_download_path="./asl_dataset"

# %% [markdown]
# ### You can see how the data looks like by uncommenting and running these statements

# %%
MSASL_test = pd.read_json("{}/msaslamericansignlanguagedataset/MSASL_test.json".format(dataset_download_path))
MSASL_test.head(10)
# Out:
#     org_text clean_text  start_time  signer_id  signer  start  end  \
# 0       beer       beer         0.0         20      40      0   59
# 1      enjoy      enjoy         0.0         11      39      0   54
# 2  emotional  emotional         0.0         20      40      0   30
# 3        key        key         0.0         92      -1      0   37
# 4        bad        bad         0.0         11      39      0   36
# 5       NEED       need         0.0         67      11      0   68
# 6      build      build         0.0         20      40      0   50
# 7     subway     subway         0.0         92      -1      0   33
# 8       pull       pull         0.0         92      43      0   32
# 9      happy      happy         0.0         11      39      0   46
#
#                    file  label  height     fps  end_time  \
# 0   SignSchool Beer var    805     360  29.970     1.969
# 1              enjoy(1)    192     360  29.970     1.802
# ...

# %%
MSASL_synonym = pd.read_json("{}/msaslamericansignlanguagedataset/MSASL_synonym.json".format(dataset_download_path))
MSASL_synonym.head(10)
# Out:
#              0           1      2     3     4
# 0       father         dad  daddy  None  None
# 1       mother         mom  mommy  None  None
# 2        shoes        shoe   None  None  None
# 3        pants        pant   None  None  None
# 4        color      colors   None  None  None
# 5    vegetable  vegetables   None  None  None
# 6      bicycle        bike   None  None  None
# 7      parents      parent   None  None  None
# 8   television          tv    t v  None  None
# 9  grandmother     grandma   None  None  None

# %%
MSASL_classes_df = pd.read_json("{}/msaslamericansignlanguagedataset/MSASL_classes.json".format(dataset_download_path))
MSASL_classes_df.head(4)
# Out:
#          0
# 0    hello
# 1     nice
# 2  teacher
# 3      eat

# %%
MSASL_train = pd.read_json("{}/msaslamericansignlanguagedataset/MSASL_train.json".format(dataset_download_path))
MSASL_train.head(10)
# Out:
#                 org_text     clean_text  start_time  signer_id  signer  start  \
# 0  match [light-a-MATCH]          match       0.000          0       0      0
# 1                   FAIL           fail       0.000          0      -1      0
# 2                  laugh          laugh       0.000          4      26      0
# 3                   BOOK           book       0.000          0      -1      0
# 4          sign-language  sign language       0.000          0      -1      0
# 5                 school         school       1.101          1      44     33
# 6                 school         school       4.671          1      44    140
# 7                 easter         easter       0.000          2      58      0
# 8                Boring          boring       0.000         13      -1      0
# 9                   PAST           past       0.000        191      13      0
#
#    end                          file  label  height     fps  end_time  \
# ...

# %%
MSASL_val = pd.read_json("{}/msaslamericansignlanguagedataset/MSASL_val.json".format(dataset_download_path))
MSASL_val.head(10)
# Out:
#           org_text clean_text  start_time  signer_id  signer  start  end  \
# 0           absent     absent         0.0        114      -1      0   37
# 1             help       help         0.0         76      42      0  110
# 2          come on    come on         0.0        114      -1      0   41
# 3         LANGUAGE   language         0.0          3      -1      0   56
# 4         confused   confused         0.0         53      -1      0   95
# 5        microwave  microwave         0.0         76      59      0   92
# 6            pizza      pizza         0.0          7      51      0   39
# 7             tape       tape         0.0          7      51      0   39
# 8         DAUGHTER   daughter         0.0         87      13      0   56
# 9  break (literal)      break         0.0        114      -1      0   58
#
#                       file  label  height     fps  end_time  \
# 0               ASL ABSENT    837     360  28.971     1.277
# ...
